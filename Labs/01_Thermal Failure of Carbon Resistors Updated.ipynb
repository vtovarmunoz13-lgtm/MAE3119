# %% [markdown]
# # Experiment 1: Thermal Failure of Carbon Resistors
#
# ## 1.1 Introduction and Purpose
#
# The purpose of this experiment is to observe the validity of Ohm's Law for resistors in common use in electronic circuitry. The effects of temperature on electrical resistance are measured by applying power to resistors at the manufacturer's rated power and beyond. By applying electrical power in both a constant voltage and a constant current mode, the feedback effect of thermal instability is observed. The experiment also serves as an aid in identifying the appearance of damaged resistors on circuit boards, and the possibility of mis-identifying color codes on thermally damaged resistors. Additionally, this experiment introduces the concept of Mean Time To Failure (MTTF) for electronic components.
#
# ## 1.2 Safety Precautions
#
# The following safety precautions should be fully understood and followed at all points during this laboratory experiment:
#
# 1. The resistor tests should all be performed over the ceramic tiles provided to prevent fires. All combustible articles, such as note paper, should be kept well away from the test area.
#
# 2. The tests should be performed with the students positioned at least three feet away from the resistor under test.
#
# 3. The debris from testing should not be handled until the power is removed and sufficient time has passed that the material has cooled off. Allow at least 5 minutes for cooling. The debris should then be stored in the metal cans provided.
#
# 4. Students with health problems or respiratory concerns should contact the lab assistant to perform an alternative exercise.
#
# 5. Always turn off the power supply before making any changes to the circuit connections.
#
#
# ## 1.3 Equipment Required
#
# The equipment supplied for this experiment includes:
#
# - 4 Hookup leads
# - Programmable power supply (KD3005P - PROGRAMMABLE PRECISION)
# - Ten 22 Ω, 1/4 Watt Resistor
# - One 22 Ω, 50 watt high power Resistor
# - Two B&K Precision 2831E Digital Multimeters (DMM)
# - Ceramic plate
#
# The equipment provided by the students is:
# - Stopwatch or timer
# - Digital camera or smartphone for taking pictures
# - Laptop with Python installed (for data recording, analysis and graphing)
#
# ## 1.4 Procedure, Part I: Color Code Identification and Tolerance Statistics
#
# 1. Set the DMM to resistance-measuring mode. Connect the black probe to the "COM" terminal and the red probe to the "VΩHz" terminal.
#
# 2. Touch the two measurement leads together. The meter should read near zero. Record this as the "residual resistance" measurement and subtract it from all subsequent resistance measurements. This compensates for the resistance of the test leads themselves.
#
# 3. Use one of the digital DMMs to measure the resistance of the 22 Ω, 50 watt high power resistor. Ensure the black probe is in the "COM" terminal and the red probe is in the "VΩHz" terminal. Write down the resistance value, which should be close to 22 Ω.
#
# 4. Measure the resistance of each of the ten 22 Ω, 1/4 watt standard resistors using the same DMM setup. Note the color code arrangement, which should read red-red-black-gold, starting with the color band nearest the end of the resistor.
#
# 5. Calculate the mean and standard deviation of the resistance for the ten standard resistors. Find the ratio of the standard deviation to the mean (coefficient of variation), and compare this value to the tolerance of the resistor.
#
#
# | Color  | 1st Band | 2nd Band | 3rd Band | Multiplier | Tolerance |
# |--------|----------|----------|----------|------------|-----------|
# | Black  | 0        | 0        | 0        | 10^0       | -         |
# | Brown  | 1        | 1        | 1        | 10^1       | ±1%       |
# | Red    | 2        | 2        | 2        | 10^2       | ±2%       |
# | Orange | 3        | 3        | 3        | 10^3       | -         |
# | Yellow | 4        | 4        | 4        | 10^4       | -         |
# | Green  | 5        | 5        | 5        | 10^5       | ±0.5%     |
# | Blue   | 6        | 6        | 6        | 10^6       | ±0.25%    |
# | Violet | 7        | 7        | 7        | 10^7       | ±0.1%     |
# | Gray   | 8        | 8        | 8        | 10^8       | ±0.05%    |
# | White  | 9        | 9        | 9        | 10^9       | -         |
# | Gold   | -        | -        | -        | 10^-1      | ±5%       |
# | Silver | -        | -        | -        | 10^-2      | ±10%      |
# | None   | -        | -        | -        | -          | ±20%      |
#
#
#
# ## 1.5 Procedure, Part II: Power Supply Setup
#
# 1. Place the 22 Ω, 50 watt high power resistor on the ceramic tile to protect the lab benchtop from heat.
#
# 2. Set up two DMMs:
#    - For voltage measurement: Set one DMM to DC voltage mode. Connect the black probe to the "COM" terminal and the red probe to the "VΩHz" terminal. Connect these across the resistor.
#    - For current measurement: Set the other DMM to DC current mode. Connect the black probe to the "COM" terminal and the red probe to the "20A" terminal. Connect this DMM in series with the resistor and power supply.
#
# 3. Set the power supply to constant voltage (CV) mode:
#    a. Use the VOLTAGE adjustment knob to set the voltage to 10.00V.
#    b. Use the CURRENT adjustment knob to set the current limit higher than expected (e.g., 1A).
#
# 2. Turn off the power supply, connect the programmable power supply (KD3005P) to the high-power resistor, using the appropriate output terminals.
#
# 6. Turn on the power supply and run this test for five minutes. The resistor should become noticeably warm but not hot. Record the voltage and current readings every 30 seconds.
#
# 7. At the end of this test, use the "Output On/Off" button on the power supply to temporarily remove power from the resistor.
#
# 8. Disconnect the resistor from the circuit. Immediately (before it cools off) measure its resistance using a DMM set to resistance mode (black probe in "COM", red probe in "VΩHz"). Record the warm resistance and set the high-power resistor aside.
#
#
# ## 1.6 Procedure, Part III: Resistor Tests and Mean Time To Failure Analysis
#
# 1. Without changing the power supply settings, replace the 22 Ω, 50 watt high power resistor with one of the 22 Ω, 1/4 watt standard resistors. Be sure that the resistor is located safely over the ceramic plate and keep your hands away from it.
#
# 2. Ensure your DMMs are still set up as in Part II and connect to the 22 Ω, 1/4 watt standard resistor.
#
# 3. Apply power by pushing the "Output On/Off" button. The resistor should be destroyed within a few seconds. Take a picture of the failed component for your report.
#
# 4. Note the final resistance of the device. If it's not visibly open-circuited, measure its resistance using a DMM in resistance mode (black probe in "COM", red probe in "VΩHz").
#
# 5. For more subtle failure modes and MTTF analysis, lower the power supplied to the device. Reset the power supply to constant voltage (CV) mode to provide 2.5 watts of DC power:
#    a. Use the VOLTAGE adjustment knob to set the voltage to 7.416 volts (=(22x2.5)^(1/2)).
#    b. Use the CURRENT adjustment knob to set the current limit higher than expected (e.g., 0.5A).
#
# 6. Remove power from the terminals using the "Output On/Off" button and then replace the failed resistor with another 22 Ω, 1/4 watt standard resistor.
#
# 7. Turn on the power supply output and start your stopwatch. Observe the current and voltage. Record each value of the current and voltage at five-second intervals until the resistor fails or ten minutes have elapsed, whichever happens first. Record the time to failure.
#
# 8. Repeat step 7 with four more 22 Ω, 1/4 watt standard resistors, recording the time to failure for each.
#
# 9. Calculate the Mean Time To Failure (MTTF) for the constant voltage test by averaging the five failure times.
#
# 10. Now set up the power supply for constant current (CC) mode with 2.5 watts of DC power:
#     a. Use the VOLTAGE adjustment knob to set the voltage limit to a high value (e.g., 15V).
#     b. Use the CURRENT adjustment knob to set the current to 0.337 ampere (=(2.5/22)^(1/2)).
#
# 11. Turn off the output, replace the failed resistor with another 22 Ω, 1/4 watt standard resistor, and apply power. Start your stopwatch. Observe and record both the voltage across the resistor and the current through it, writing down the values every five seconds until failure or ten minutes, whichever comes first. Record the time to failure.
#
# 12. Repeat step 11 with the remaining four 22 Ω, 1/4 watt standard resistors, recording the time to failure for each.
#
# 13. Calculate the Mean Time To Failure (MTTF) for the constant current test by averaging the five failure times.
#
# 14. Compare the MTTF and failure characteristics between the constant voltage and constant current tests.
#
# ## 1.7 Data Analysis
#
# 1. After completing all tests, review your collected data in your lab notebook.
#
# 2. Use Python to perform the following analyses and create graphs:
#    - Plot voltage vs. time, current vs. time, and resistance vs. time for both constant voltage and constant current tests.
#    - Compare the time to failure for constant voltage vs. constant current tests
#    - Analyze the relationship between power and time to failure
#    - Investigate any patterns in resistance changes over time
#    - Create histograms of failure times for both CV and CC tests
#    - Calculate and plot the MTTF for both CV and CC tests
#
# 3. Document your findings and observations in your lab report.
#
# Python Code Template:
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # Sample data (replace with your actual data)
# time = np.array([0, 5, 10, 15, 20])  # Time in seconds
# voltage = np.array([7.416, 7.4, 7.3, 7.2, 7.0])  # Voltage in volts
# current = np.array([0.337, 0.34, 0.35, 0.36, 0.37])  # Current in amperes
#
# # Calculate resistance and power
# resistance = voltage / current
# power = voltage * current
#
# # Create plots
# plt.figure(figsize=(12, 8))
#
# plt.subplot(2, 2, 1)
# plt.plot(time, voltage)
# plt.title('Voltage vs Time')
# plt.xlabel('Time (s)')
# plt.ylabel('Voltage (V)')
#
# plt.subplot(2, 2, 2)
# plt.plot(time, current)
# plt.title('Current vs Time')
# plt.xlabel('Time (s)')
# plt.ylabel('Current (A)')
#
# plt.subplot(2, 2, 3)
# plt.plot(time, resistance)
# plt.title('Resistance vs Time')
# plt.xlabel('Time (s)')
# plt.ylabel('Resistance (Ω)')
#
# plt.subplot(2, 2, 4)
# plt.plot(time, power)
# plt.title('Power vs Time')
# plt.xlabel('Time (s)')
# plt.ylabel('Power (W)')
#
# plt.tight_layout()
# plt.show()
#
# # MTTF Analysis
# cv_failure_times = [100, 120, 95, 110, 105]  # Replace with your actual data
# cc_failure_times = [90, 115, 100, 105, 95]   # Replace with your actual data
#
# plt.figure(figsize=(10, 5))
#
# plt.subplot(1, 2, 1)
# plt.hist(cv_failure_times, bins=5)
# plt.title('Constant Voltage Failure Times')
# plt.xlabel('Time to Failure (s)')
# plt.ylabel('Frequency')
#
# plt.subplot(1, 2, 2)
# plt.hist(cc_failure_times, bins=5)
# plt.title('Constant Current Failure Times')
# plt.xlabel('Time to Failure (s)')
# plt.ylabel('Frequency')
#
# plt.tight_layout()
# plt.show()
#
# print(f"MTTF for Constant Voltage: {np.mean(cv_failure_times):.2f} seconds")
# print(f"MTTF for Constant Current: {np.mean(cc_failure_times):.2f} seconds")
# ```
#
# ## 1.8 Laboratory Report
#
# Each student shall submit a report on all of the tests performed in laboratory. The lab report organization is as follows:
#
# 1. Abstract: giving the pertinent details of what experiments were performed and the general outcome
# 2. Description of the experimental setups used
# 3. Tabulation of all data, including figures and tables, pictures of physical changes of the test specimens, and verbal description of failure modes
# 4. Analysis of data, including comments concerning connection of the experiments to physical understanding
# 5. Mean Time To Failure (MTTF) analysis for both constant voltage and constant current tests
# 6. Python code used for data analysis and generated plots or figures
# 7. Conclusions, such as validity of the test techniques, sources of error, general observations, and recommendations to future investigators
#
# ## 1.9 Additional Questions for Laboratory Report
#
# 1. With the addition of heat, some color bands can shift. Red often becomes brown. Did any of your resistors become modified by heat so that they had a "correct" resistance for a color code of brown-brown-black at some point? What resistance is this?
#
# 2. From your statistical study of the fresh quarter-watt resistors, how did the standard deviation, expressed as a percentage, compare to the stated tolerance of the resistors? What fraction of the batch of resistors would you expect to be out of tolerance? (Hint: use a Gaussian probability distribution.)
#
# 3. Why do resistors operating at constant current fail at different rates from resistors at constant voltage, for the same initial power level?
#
# 4. Compare the Mean Time To Failure (MTTF) between the constant voltage and constant current tests. What might account for any differences observed?
#
# 5. Suppose that the failure rate of resistors follows a law like MTTF = kP^(-m), where m is an adjustable exponent and P is the power. A resistor operating at its rated power has a mean time to failure (MTTF) of five years. What value of m best describes your results?
#
# 6. How do you think the mounting of the resistor on a printed circuit board affects its power handling ability? Would these resistors be safe on a combustible substrate, like polyethylene? What precautions would you take in using circuits with these resistors for instrumentation in an oil well?
#
# 7. Resistors are cheaper than fuses and are often used to protect a more valuable component, such as a large integrated circuit, from damage. What is the equivalent "fuse current rating" of the 22 Ω, 1/4 W resistors you studied, to open within ten seconds?
